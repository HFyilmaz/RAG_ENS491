# %% [markdown]
# # ZIPFILE CSV

# %%
import zipfile
import xml.etree.ElementTree as ET
import csv

# Define the namespace used in WordprocessingML
WORD_NAMESPACE = '{http://schemas.openxmlformats.org/wordprocessingml/2006/main}'
PARA = WORD_NAMESPACE + 'p'
TEXT = WORD_NAMESPACE + 't'
TABLE = WORD_NAMESPACE + 'tbl'
ROW = WORD_NAMESPACE + 'tr'
CELL = WORD_NAMESPACE + 'tc'

# Open the docx file as a zip archive and read the document.xml file
with zipfile.ZipFile('reg3.docx') as docx:
    tree = ET.XML(docx.read('word/document.xml'))

# Iterate over tables and extract text from each cell
table_count = 1  # To keep track of table number for naming files
for table in tree.iter(TABLE):
    table_data = []  # List to store rows for the current table
    
    for row in table.iter(ROW):
        row_data = []  # List to hold the data of a single row
        for cell in row.iter(CELL):
            cell_text = ''.join(node.text or '' for node in cell.iter(TEXT))
            if cell_text.strip():  # Only add non-empty cells
                row_data.append(cell_text.strip())
        if row_data:  # Only append rows that have data
            table_data.append(row_data)
    
    # Save each table to a separate CSV file
    if table_data:  # If there's data in the table
        csv_filename = f'table{table_count}.csv'
        with open(csv_filename, 'w', newline='') as f:
            writer = csv.writer(f)
            writer.writerows(table_data)
        
        print(f"Table {table_count} data has been saved to {csv_filename}")
        table_count += 1  # Increment to get the next table number
# Out:
# Table 1 data has been saved to table1.csv
# Table 2 data has been saved to table2.csv
# Table 3 data has been saved to table3.csv
# Table 4 data has been saved to table4.csv
# Table 5 data has been saved to table5.csv

# %% [markdown]
# # CSV TABULAR FORMAT

# %%
import pandas as pd
from docx import Document

# Load the Word document
document = Document('reg3.docx')

# Get all the tables in the document
tables = document.tables

# Iterate over each table
for table_index, table in enumerate(tables):
    data = []  # List to store row data for the current table
    keys = None  # Will store the header keys for the current table
    
    # Iterate over the rows in the table
    for i, row in enumerate(table.rows):
        text = (cell.text.strip() for cell in row.cells)  # Strip extra spaces
        
        if i == 0:
            keys = tuple(text)  # First row is considered as column headers
            continue
        
        # Create a dictionary with keys as column headers and row values
        row_data = dict(zip(keys, text))
        data.append(row_data)
    
    # Create a DataFrame for the current table
    df = pd.DataFrame(data)
    
    # Create a dynamic filename for each table (e.g., table1.csv, table2.csv, etc.)
    csv_filename = f'table{table_index + 1}.csv'
    
    # Save the DataFrame as a CSV file
    df.to_csv(csv_filename, index=False)
    
    # Print the DataFrame for this table
    print(f"DataFrame for Table {table_index + 1} saved as {csv_filename}")
    print(df)
    print("\n" + "-"*40 + "\n")
# Out:
# DataFrame for Table 1 saved as table1.csv
#     E/ECE/324/Add.2/Rev.5−E/ECE/TRANS/505/Add.2/Rev.5
# 0                                         9 June 2020
#
# ----------------------------------------
#
# DataFrame for Table 2 saved as table2.csv
#         Class Angle of divergence\nα Illumination angles (in degrees)
# 0                                                           ±5°\n±20°
# 1      IA, IB             20'\n1°30'                         100\n2.5
# 2  IIIA, IIIB             20'\n1°30'                           150\n8
#
# ----------------------------------------
#
# DataFrame for Table 3 saved as table3.csv
#   Colour Angle of divergence\nα Illumination angles (in degrees)
# 0                                                         0\n±50
# 1  White             20'\n1°30'                          400\n15
# 2  Amber             20'\n1°30'                          250\n10
# 3    Red             20'\n1°30'                           100\n4
#
# ----------------------------------------
#
# DataFrame for Table 4 saved as table4.csv
#           Number of annex    Number of paragraph  \
# 0
# 1                       -                    6.*
# 2                       5                      -
# 3                      10                      -
# 4                       6                      -
# 5                       7                      -
# 6                       7                     3.
# 7                       8                     1.
# 8                       4                   3.1.
# 9                       4                   3.2.
# 10                      8                     3.
# 11                      8                     4.
# 12                      4                   3.1.
# 13                      4                   3.2.
# 14                      8                     2.
# 15                      8                     5.
# 16                      4                   3.1.
# 17                      4                   3.2.
# 18                      9                      -
# 19                      4                   3.1.
# 20                      4                   3.2.
# 21                     11                      -
# 22                      4                   3.1.
# 23                      4                   3.2.
# 24                      4                     2.
# 25  *  of the Regulation.  *  of the Regulation.
#
#                                                 Tests                Samples
# 0                                                                          j
# 1           General specifications: visual inspection                      x
# 2            Shapes and dimensions: visual inspection                      x
# 3   Heat: \t48 h at 65° ± 2°C\n\tVisual inspection...                   x\nx
# 4   Colorimetry: visual inspection\nTrichromatic c...                      x
# 5           Photometry: limited to 20' and V = H = 0°                      x
# 6                                 Complete photometry
# 7   Water: \t10 min. in normal position\n\t\t10 mi...
# 8   Colorimetry:\tvisual inspection\nTrichromatic ...
# 9           Photometry: limited to 20' and V = H = 0°
# 10        Motor fuels:\t5 min.\n\t\tvisual inspection
# 11             Oils:\t\t5 min.\n\t\tvisual inspection
# 12  Colorimetry: visual inspection\nTrichromatic c...
# 13          Photometry: limited to 20' and V = H = 0°
# 14  Corrosion:\t24 hours\n\t\t2 hours interval\n\t...
# 15          Rear face:\t1 min.\n\t\tvisual inspection
# 16  Colorimetry: visual inspection\nTrichromatic c...
# 17          Photometry: limited to 20' and V = H = 0°
# 18                                  Stability in time
# 19  Colorimetry: Visual inspection or trichromatic...
# 20          Photometry: limited to 20' and V = H = 0°
# 21                                    Colour-fastness
# 22  Colorimetry: \tVisual inspection or\n\t\ttrich...
# 23          Photometry: limited to 20' and V = H = 0°
# 24                  Deposit of samples with authority
# 25                              *  of the Regulation.  *  of the Regulation.
#
# ----------------------------------------
#
# DataFrame for Table 5 saved as table5.csv
#           Number of annex    Number of paragraph  \
# 0
# 1                       -                    6.*
# 2                       5                      -
# 3                      10                      -
# 4                       6                      -
# 5                       7                      -
# 6                       7                      -
# 7                       8                     1.
# 8                       8                     3.
# 9                       8                     4.
# 10                      6                      -
# 11                      7                      -
# 12                      8                     2.
# 13                      8                     5.
# 14                     13                      -
# 15                      6                      -
# 16                      7                      -
# 17                     14                     2.
# 18  *  of the Regulation.  *  of the Regulation.
#
#                                                 Tests                Samples
# 0                                                                          j
# 1           General specifications: visual inspection                      x
# 2             Shape and dimensions: visual inspection                      x
# 3   Heat:\t48 h at 65 °C ± 20°C\n\tVisual inspecti...                   x\nx
# 4   Colorimetry: visual inspection\nTrichromatic c...                      x
# 5           Photometry: limited to 20' and V = H = 0°                      x
# 6                                 Complete photometry
# 7   Water:\t10 min. in normal position\n\t\t10 min...
# 8         Motor fuels:\t5 min.\n\t\tvisual inspection
# 9              Oils:\t\t5 min.\n\t\tvisual inspection
# 10  Colorimetry: visual inspection\nTrichromatic c...
# 11          Photometry: limited to 20' and V = H = 0°
# 12  Corrosion:\t24 hours\n\t\t2 hours' interval\n\...
# 13          Rear face:\t1 min.\n\t\tvisual inspection
# 14                      Impact\n\t\tvisual inspection
# 15  Colorimetry: visual inspection\nTrichromatic c...
# 16          Photometry: limited to 20' and V = H = 0°
# 17                  Deposit of samples with Authority
# 18                              *  of the Regulation.  *  of the Regulation.
#
# ----------------------------------------

# %% [markdown]
# # JSON TABULAR FORMAT

# %%
import pandas as pd
from docx import Document

# Load the Word document
document = Document('reg3.docx')

# Get all the tables in the document
tables = document.tables

# Iterate over each table
for table_index, table in enumerate(tables):
    data = []  # List to store row data for the current table
    keys = None  # Will store the header keys for the current table
    
    # Iterate over the rows in the table
    for i, row in enumerate(table.rows):
        text = (cell.text.strip() for cell in row.cells)  # Strip extra spaces
        
        if i == 0:
            keys = tuple(text)  # First row is considered as column headers
            continue
        
        # Create a dictionary with keys as column headers and row values
        row_data = dict(zip(keys, text))
        data.append(row_data)
    
    # Create a DataFrame for the current table
    df = pd.DataFrame(data)
    
    # Create a dynamic filename for each table (e.g., table1.json, table2.json, etc.)
    json_filename = f'table{table_index + 1}.json'
    
    # Save the DataFrame as a JSON file
    df.to_json(json_filename, orient='records', lines=True)  # orient='records' for a list of dicts
    
    # Print the DataFrame for this table
    print(f"DataFrame for Table {table_index + 1} saved as {json_filename}")
    print(df)
    print("\n" + "-"*40 + "\n")
# Out:
# DataFrame for Table 1 saved as table1.json
#     E/ECE/324/Add.2/Rev.5−E/ECE/TRANS/505/Add.2/Rev.5
# 0                                         9 June 2020
#
# ----------------------------------------
#
# DataFrame for Table 2 saved as table2.json
#         Class Angle of divergence\nα Illumination angles (in degrees)
# 0                                                           ±5°\n±20°
# 1      IA, IB             20'\n1°30'                         100\n2.5
# 2  IIIA, IIIB             20'\n1°30'                           150\n8
#
# ----------------------------------------
#
# DataFrame for Table 3 saved as table3.json
#   Colour Angle of divergence\nα Illumination angles (in degrees)
# 0                                                         0\n±50
# 1  White             20'\n1°30'                          400\n15
# 2  Amber             20'\n1°30'                          250\n10
# 3    Red             20'\n1°30'                           100\n4
#
# ----------------------------------------
#
# DataFrame for Table 4 saved as table4.json
#           Number of annex    Number of paragraph  \
# 0
# 1                       -                    6.*
# 2                       5                      -
# 3                      10                      -
# 4                       6                      -
# 5                       7                      -
# 6                       7                     3.
# 7                       8                     1.
# 8                       4                   3.1.
# 9                       4                   3.2.
# 10                      8                     3.
# 11                      8                     4.
# 12                      4                   3.1.
# 13                      4                   3.2.
# 14                      8                     2.
# 15                      8                     5.
# 16                      4                   3.1.
# 17                      4                   3.2.
# 18                      9                      -
# 19                      4                   3.1.
# 20                      4                   3.2.
# 21                     11                      -
# 22                      4                   3.1.
# 23                      4                   3.2.
# 24                      4                     2.
# 25  *  of the Regulation.  *  of the Regulation.
#
#                                                 Tests                Samples
# 0                                                                          j
# 1           General specifications: visual inspection                      x
# 2            Shapes and dimensions: visual inspection                      x
# 3   Heat: \t48 h at 65° ± 2°C\n\tVisual inspection...                   x\nx
# 4   Colorimetry: visual inspection\nTrichromatic c...                      x
# 5           Photometry: limited to 20' and V = H = 0°                      x
# 6                                 Complete photometry
# 7   Water: \t10 min. in normal position\n\t\t10 mi...
# 8   Colorimetry:\tvisual inspection\nTrichromatic ...
# 9           Photometry: limited to 20' and V = H = 0°
# 10        Motor fuels:\t5 min.\n\t\tvisual inspection
# 11             Oils:\t\t5 min.\n\t\tvisual inspection
# 12  Colorimetry: visual inspection\nTrichromatic c...
# 13          Photometry: limited to 20' and V = H = 0°
# 14  Corrosion:\t24 hours\n\t\t2 hours interval\n\t...
# 15          Rear face:\t1 min.\n\t\tvisual inspection
# 16  Colorimetry: visual inspection\nTrichromatic c...
# 17          Photometry: limited to 20' and V = H = 0°
# 18                                  Stability in time
# 19  Colorimetry: Visual inspection or trichromatic...
# 20          Photometry: limited to 20' and V = H = 0°
# 21                                    Colour-fastness
# 22  Colorimetry: \tVisual inspection or\n\t\ttrich...
# 23          Photometry: limited to 20' and V = H = 0°
# 24                  Deposit of samples with authority
# 25                              *  of the Regulation.  *  of the Regulation.
#
# ----------------------------------------
#
# DataFrame for Table 5 saved as table5.json
#           Number of annex    Number of paragraph  \
# 0
# 1                       -                    6.*
# 2                       5                      -
# 3                      10                      -
# 4                       6                      -
# 5                       7                      -
# 6                       7                      -
# 7                       8                     1.
# 8                       8                     3.
# 9                       8                     4.
# 10                      6                      -
# 11                      7                      -
# 12                      8                     2.
# 13                      8                     5.
# 14                     13                      -
# 15                      6                      -
# 16                      7                      -
# 17                     14                     2.
# 18  *  of the Regulation.  *  of the Regulation.
#
#                                                 Tests                Samples
# 0                                                                          j
# 1           General specifications: visual inspection                      x
# 2             Shape and dimensions: visual inspection                      x
# 3   Heat:\t48 h at 65 °C ± 20°C\n\tVisual inspecti...                   x\nx
# 4   Colorimetry: visual inspection\nTrichromatic c...                      x
# 5           Photometry: limited to 20' and V = H = 0°                      x
# 6                                 Complete photometry
# 7   Water:\t10 min. in normal position\n\t\t10 min...
# 8         Motor fuels:\t5 min.\n\t\tvisual inspection
# 9              Oils:\t\t5 min.\n\t\tvisual inspection
# 10  Colorimetry: visual inspection\nTrichromatic c...
# 11          Photometry: limited to 20' and V = H = 0°
# 12  Corrosion:\t24 hours\n\t\t2 hours' interval\n\...
# 13          Rear face:\t1 min.\n\t\tvisual inspection
# 14                      Impact\n\t\tvisual inspection
# 15  Colorimetry: visual inspection\nTrichromatic c...
# 16          Photometry: limited to 20' and V = H = 0°
# 17                  Deposit of samples with Authority
# 18                              *  of the Regulation.  *  of the Regulation.
#
# ----------------------------------------

# %% [markdown]
# # STRINGIFIED TABULAR DATA

# %%
import pandas as pd
from docx import Document

# Function to convert DataFrame to a string representation
def df_to_string(df):
    return df.to_string(index=False)  # Convert DataFrame to string without the index

# Load the Word document
document = Document('reg3.docx')

# Get all the tables in the document
tables = document.tables

# Iterate over each table
for table_index, table in enumerate(tables):
    data = []  # List to store row data for the current table
    keys = None  # Will store the header keys for the current table
    
    # Iterate over the rows in the table
    for i, row in enumerate(table.rows):
        text = (cell.text.strip() for cell in row.cells)  # Strip extra spaces
        
        if i == 0:
            keys = tuple(text)  # First row is considered as column headers
            continue
        
        # Create a dictionary with keys as column headers and row values
        row_data = dict(zip(keys, text))
        data.append(row_data)
    
    # Create a DataFrame for the current table
    df = pd.DataFrame(data)
    
    # Convert the DataFrame to a string
    df_string = df_to_string(df)
    
    # Print the stringified DataFrame for the current table
    print(f"Stringified DataFrame for Table {table_index + 1}:")
    print(df_string)
    print("\n" + "-"*40 + "\n")
# Out:
# Stringified DataFrame for Table 1:
#  E/ECE/324/Add.2/Rev.5−E/ECE/TRANS/505/Add.2/Rev.5
#                                        9 June 2020
#
# ----------------------------------------
#
# Stringified DataFrame for Table 2:
#      Class Angle of divergence\nα Illumination angles (in degrees)
#                                                          ±5°\n±20°
#     IA, IB             20'\n1°30'                         100\n2.5
# IIIA, IIIB             20'\n1°30'                           150\n8
#
# ----------------------------------------
#
# Stringified DataFrame for Table 3:
# Colour Angle of divergence\nα Illumination angles (in degrees)
#                                                         0\n±50
#  White             20'\n1°30'                          400\n15
#  Amber             20'\n1°30'                          250\n10
#    Red             20'\n1°30'                           100\n4
#
# ----------------------------------------
#
# Stringified DataFrame for Table 4:
#       Number of annex   Number of paragraph                                                                                        Tests               Samples
#                                                                                                                                                              j
#                     -                   6.*                                                    General specifications: visual inspection                     x
#                     5                     -                                                     Shapes and dimensions: visual inspection                     x
#                    10                     -                                Heat: \t48 h at 65° ± 2°C\n\tVisual inspection for distortion                  x\nx
#                     6                     -                    Colorimetry: visual inspection\nTrichromatic coordinates in case of doubt                     x
#                     7                     -                                                    Photometry: limited to 20' and V = H = 0°                     x
#                     7                    3.                                                                          Complete photometry
#                     8                    1. Water: \t10 min. in normal position\n\t\t10 min. in inverted position\n\t\tvisual inspection
#                     4                  3.1.                   Colorimetry:\tvisual inspection\nTrichromatic coordinates in case of doubt
#                     4                  3.2.                                                    Photometry: limited to 20' and V = H = 0°
#                     8                    3.                                                  Motor fuels:\t5 min.\n\t\tvisual inspection
#                     8                    4.                                                       Oils:\t\t5 min.\n\t\tvisual inspection
#                     4                  3.1.                    Colorimetry: visual inspection\nTrichromatic coordinates in case of doubt
#                     4                  3.2.                                                    Photometry: limited to 20' and V = H = 0°
#                     8                    2.              Corrosion:\t24 hours\n\t\t2 hours interval\n\t\t24 hours\n\t\tvisual inspection
#                     8                    5.                                                    Rear face:\t1 min.\n\t\tvisual inspection
#                     4                  3.1.                    Colorimetry: visual inspection\nTrichromatic coordinates in case of doubt
#                     4                  3.2.                                                    Photometry: limited to 20' and V = H = 0°
#                     9                     -                                                                            Stability in time
#                     4                  3.1.                                   Colorimetry: Visual inspection or trichromatic coordinates
#                     4                  3.2.                                                    Photometry: limited to 20' and V = H = 0°
#                    11                     -                                                                              Colour-fastness
#                     4                  3.1.                            Colorimetry: \tVisual inspection or\n\t\ttrichromatic coordinates
#                     4                  3.2.                                                    Photometry: limited to 20' and V = H = 0°
#                     4                    2.                                                            Deposit of samples with authority
# *  of the Regulation. *  of the Regulation.                                                                        *  of the Regulation. *  of the Regulation.
#
# ----------------------------------------
#
# Stringified DataFrame for Table 5:
#       Number of annex   Number of paragraph                                                                                       Tests               Samples
#                                                                                                                                                             j
#                     -                   6.*                                                   General specifications: visual inspection                     x
#                     5                     -                                                     Shape and dimensions: visual inspection                     x
#                    10                     -                             Heat:\t48 h at 65 °C ± 20°C\n\tVisual inspection for distortion                  x\nx
#                     6                     -                   Colorimetry: visual inspection\nTrichromatic coordinates in case of doubt                     x
#                     7                     -                                                   Photometry: limited to 20' and V = H = 0°                     x
#                     7                     -                                                                         Complete photometry
#                     8                    1. Water:\t10 min. in normal position\n\t\t10 min. in inverted position\n\t\tvisual inspection
#                     8                    3.                                                 Motor fuels:\t5 min.\n\t\tvisual inspection
#                     8                    4.                                                      Oils:\t\t5 min.\n\t\tvisual inspection
#                     6                     -                   Colorimetry: visual inspection\nTrichromatic coordinates in case of doubt
#                     7                     -                                                   Photometry: limited to 20' and V = H = 0°
#                     8                    2.            Corrosion:\t24 hours\n\t\t2 hours' interval\n\t\t24 hours\n\t\tvisual inspection
#                     8                    5.                                                   Rear face:\t1 min.\n\t\tvisual inspection
#                    13                     -                                                               Impact\n\t\tvisual inspection
#                     6                     -                   Colorimetry: visual inspection\nTrichromatic coordinates in case of doubt
#                     7                     -                                                   Photometry: limited to 20' and V = H = 0°
#                    14                    2.                                                           Deposit of samples with Authority
# *  of the Regulation. *  of the Regulation.                                                                       *  of the Regulation. *  of the Regulation.
#
# ----------------------------------------

# %% [markdown]
# # TEXT ONLY EXTRACTION

# %%
import docx

def saveText(filename, output_txt):
    # Load the document
    doc = docx.Document(filename)
    with open(output_txt, 'w', encoding='utf-8') as file:
        # Iterate over paragraphs and write to the output file
        for para in doc.paragraphs:
            file.write(para.text + '\n')  # Adds each paragraph with a newline

# %%
# Example usage
saveText('reg6.docx', 'output.txt')
